# %% [markdown]
# # data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # matplot lib basics

# %%
# numpy array - linspace - linear space 
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x ** 3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
#plot - makes a line graph 
plt.plot(x,y)
# graph title
plt.title("hello ji")
# x label 
plt.xlabel("blah blue")
#y label
plt.ylabel("bleh blue")
# Out:
# Text(0, 0.5, 'bleh blue')

# %% [markdown]
# # subplots in matplotlib

# %%
# ek sath multiple plots 
# you need to provide rows and columns 
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(y,x)

# %%
plt.subplot(6,6,1)
plt.subplot(6,6,2)
plt.subplot(6,6,3)
plt.subplot(6,6,4)
plt.subplot(6,6,5)
plt.subplot(6,6,6)
plt.subplot(6,6,7)
plt.subplot(6,6,30)
plt.subplot(6,6,36)
# Out:
# <Axes: >

# %% [markdown]
# # OBJECT ORIENTED WAY

# %%
# CREATE AN OBJECT 
fig = plt.figure(figsize=(9,8),dpi=100)
# ADD AXES -  PROVIDE 4 THINGS 
#  axes_name = fig.add_axes([left, bottom, width, height])
axis1 = fig.add_axes([0.1,0.1,1,1])
#plotting on axis1 
axis1.plot(x,y)
#create axis2 
axis2 = fig.add_axes([0.3,0.4,0.3,0.3])
axis2.plot(x,y)

# %% [markdown]
# TYPES OF PLOTS

# %% [markdown]
# - scatter plot

# %%
plt.scatter(x,y)

# %% [markdown]
#  - histogram

# %%
# import sample 
from random import sample 
#sample data 
data = sample(range(1,1000),100)
# plot histogram
plt.hist(data)
# Out:
# (array([13.,  6., 10.,  8., 13., 11., 12.,  4., 11., 12.]),
#  array([ 10. , 108.6, 207.2, 305.8, 404.4, 503. , 601.6, 700.2, 798.8,
#         897.4, 996. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# - boxplot

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a195fb2b40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a195fb1700>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a195fb1a60>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a195fb2720>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a196dc4140>],
#  'means': []}

# %% [markdown]
#  SAVING PLOTS

# %%
#FIGURE
fig = plt.figure()
#ADD AXES 
ax=fig.add_axes([0.1,0.1,0.8,0.8])
# PLOT 
ax.plot(x,y)
#SAVE 
plt.savefig("basicplot.png")

# %% [markdown]
# WORKING WITH IMAGES

# %%
# IMPORT MATPLOTLIB.IMAGES 
import matplotlib.image as mpimg

# %%
# load the image 
img = mpimg.imread('images.jpeg')
# show image 
plt.imshow(img)
# remove axis
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(451.5), np.float64(677.5), np.float64(-0.5))

# %%
# crop image 
cropped_img= img[50:200,100:300]
# show image 
plt.imshow(cropped_img)
# remove axis
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(149.5), np.float64(-0.5))

# %% [markdown]
# OPTIONAL DESIGNING
