# %% [markdown]
# # data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # matplot lib basics

# %%
# numpy array - linspace - linear space 
x = np.linspace(0,5,11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x ** 3
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
#plot - makes a line graph 
plt.plot(x,y)
# graph title
plt.title("hello ji")
# x label 
plt.xlabel("blah blue")
#y label
plt.ylabel("bleh blue")
# Out:
# Text(0, 0.5, 'bleh blue')

# %% [markdown]
# # subplots in matplotlib

# %%
# ek sath multiple plots 
# you need to provide rows and columns 
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.plot(x**2,x**2)
plt.subplot(2,2,4)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(y,x)
